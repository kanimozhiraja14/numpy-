# %%
import pandas as  pd

# %%
print(pd.__version__)
# Out:
# 2.3.3

# %%
age=[25,22,5,2,24]

# %%
series = pd.Series(age)

# %%
print(series)
# Out:
# 0    25
# 1    22
# 2     5
# 3     2
# 4    24
# dtype: int64

# %%
age=[2.5,2.2,5.6,2.3,2.4]

# %%
series = pd.Series(age)

# %%
print(series)
# Out:
# 0    2.5
# 1    2.2
# 2    5.6
# 3    2.3
# 4    2.4
# dtype: float64

# %%
import  pandas as pd

# %%
age=[12,13,14,15]

# %%
series = pd.Series(age, index=["kani","kavi","lathi","janani"])
print(series)
# Out:
# kani      12
# kavi      13
# lathi     14
# janani    15
# dtype: int64

# %%
print(series.loc["kani"])
# Out:
# 12

# %%
print(series.iloc[1])
# Out:
# 13

# %%
age={

    "kani":25,
    "lathi":17,
    "kavi":16
}

# %%
series=pd.Series(age)

# %%
print(series)
# Out:
# kani     25
# lathi    17
# kavi     16
# dtype: int64
