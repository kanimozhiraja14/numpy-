# %%
import pandas as pd

# %%
students={
    "name":["kani","lathi","kavi"],
    "age":[19,20,21],
    "cgpa":[7.5,6.7,8.5]
}

# %%
df = pd.DataFrame(students)

# %%
print(df)
# Out:
#     name  age  cgpa
# 0   kani   19   7.5
# 1  lathi   20   6.7
# 2   kavi   21   8.5

# %%
df = pd.DataFrame(students, index=["std1","std2","std3"])

# %%
print(df)
# Out:
#        name  age  cgpa
# std1   kani   19   7.5
# std2  lathi   20   6.7
# std3   kavi   21   8.5

# %%
print(df.loc["std2"])
# Out:
# name    lathi
# age        20
# cgpa      6.7
# Name: std2, dtype: object

# %%
print(df.iloc[2])
# Out:
# name    kavi
# age       21
# cgpa     8.5
# Name: std3, dtype: object

# %%
df["class"] = ["first","second","third"]

# %%
print(df)
# Out:
#        name  age  cgpa   class
# std1   kani   19   7.5   first
# std2  lathi   20   6.7  second
# std3   kavi   21   8.5   third

# %%
std4 = pd.DataFrame({"name":"undefine","age":22,"cgpa":5.6}, index=["std4"])

# %%
df = pd.concat([df, std4])
print(df)
# Out:
#           name  age  cgpa   class
# std1      kani   19   7.5   first
# std2     lathi   20   6.7  second
# std3      kavi   21   8.5   third
# std4  undefine   22   5.6     NaN

# %%
students = pd.DataFrame([{"name":"undefine","age":22,"cgpa":5.6},
                        {"name":"logi io","age":24,"cgpa":8.6},
                        {"name":"gn","age":26,"cgpa":9.6}],
                        index=["std5","std6","std7"])

# %%
df = pd.concat([df, students])
print(df)
# Out:
#           name  age  cgpa   class
# std1      kani   19   7.5   first
# std2     lathi   20   6.7  second
# std3      kavi   21   8.5   third
# std4  undefine   22   5.6     NaN
# std5  undefine   22   5.6     NaN
# std6   logi io   24   8.6     NaN
# std7        gn   26   9.6     NaN
