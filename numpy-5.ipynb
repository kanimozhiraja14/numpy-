# %%
import numpy as np

# %%
arr=np.array([25,24,5,2])

# %%
print(arr+1)
# Out:
# [26 25  6  3]

# %%
brr=np.sqrt(arr)

# %%
print(np.round(brr))
# Out:
# [5. 5. 2. 1.]

# %%
print(np.floor(brr))
# Out:
# [5. 4. 2. 1.]

# %%
print(np.ceil(brr))
# Out:
# [5. 5. 3. 2.]

# %% [raw]
# brr=np.array([1,2,3,4])

# %%
print(arr+brr)
# Out:
# [30.         28.89897949  7.23606798  3.41421356]

# %%
age = np.array([25,24,53,50,18,6,17])

# %%
print(age < 18)
# Out:
# [False False False False False  True  True]

# %%
print(age == 18)
# Out:
# [False False False False  True False False]

# %%
print(age >= 18)
# Out:
# [ True  True  True  True  True False False]

# %%
age[age<18] = 18
print(age)
# Out:
# [25 24 53 50 18 18 18]

# %%
age[age>50] = 50
print(age)
# Out:
# [25 24 50 50 18 18 18]
