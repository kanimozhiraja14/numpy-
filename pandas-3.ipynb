# %%
import pandas as pd

# %%
df = pd.read_csv("customers-100.csv")

# %%
print(df.head())
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
print(df.to_string())
# Out:
#     Index      Customer Id  First Name    Last Name                          Company                 City                                       Country                 Phone 1                 Phone 2                               Email Subscription Date                            Website
# 0       1  DD37Cf93aecA6Dc      Sheryl       Baxter                  Rasmussen Group         East Leonard                                         Chile            229.077.5154        397.884.0519x718            zunigavanessa@smith.info        2020-08-24         http://www.stephenson.com/
# 1       2  1Ef7b82A4CAAD10     Preston       Lozano                      Vega-Gentry    East Jimmychester                                      Djibouti              5153435776        686-620-1820x944                     vmata@colon.com        2021-04-23              http://www.hobbs.com/
# ...

# %%
print(df)
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
print(df['City'])
# Out:
# 0          East Leonard
# 1     East Jimmychester
# 2         Isabelborough
# 3            Bensonview
# 4        West Priscilla
#             ...
# 95         East Richard
# 96         New Bradview
# 97           Ortegaland
# 98      Lake Elijahview
# 99            Judymouth
# Name: City, Length: 100, dtype: object

# %%
print(df['City'].to_string())
# Out:
# 0            East Leonard
# 1       East Jimmychester
# 2           Isabelborough
# 3              Bensonview
# 4          West Priscilla
# 5           Chavezborough
# 6                Lake Ana
# 7                 Kimport
# 8            Robersonstad
# 9              Elaineberg
# 10           Shannonville
# 11            East Andrea
# 12      South Joannamouth
# 13               Jodyberg
# 14              Burchbury
# 15           Desireeshire
# 16      West Adriennestad
# 17            Lake Leslie
# 18             Harmonview
# 19             Jamesshire
# 20             East Carly
# 21            South Alvin
# 22           Brittanyview
# 23          Veronicamouth
# 24             Bryanville
# 25            Kaitlyntown
# 26           Michealshire
# 27      South Marissatown
# 28           Acevedoville
# 29           North Harold
# 30            West Samuel
# 31      Cunninghamborough
# 32          Port Annatown
# 33            New Kaitlyn
# 34       West Marthaburgh
# ...

# %%
print(df["Country"].to_string())
# Out:
# 0                                            Chile
# 1                                         Djibouti
# 2                              Antigua and Barbuda
# 3                               Dominican Republic
# 4                       Slovakia (Slovak Republic)
# 5                           Bosnia and Herzegovina
# 6                                 Pitcairn Islands
# 7                                         Bulgaria
# 8                                           Cyprus
# 9                                      Timor-Leste
# 10                                        Guernsey
# 11                                         Vietnam
# 12                                            Togo
# 13                                       Sri Lanka
# 14                                       Singapore
# 15                                            Oman
# 16                                  Western Sahara
# 17                                      Mozambique
# ...

# %%
print(df[["Customer Id","First Name","Country","City"]])
# Out:
#         Customer Id First Name                     Country               City
# 0   DD37Cf93aecA6Dc     Sheryl                       Chile       East Leonard
# 1   1Ef7b82A4CAAD10    Preston                    Djibouti  East Jimmychester
# 2   6F94879bDAfE5a6        Roy         Antigua and Barbuda      Isabelborough
# 3   5Cef8BFA16c5e3c      Linda          Dominican Republic         Bensonview
# 4   053d585Ab6b3159     Joanna  Slovakia (Slovak Republic)     West Priscilla
# ..              ...        ...                         ...                ...
# 95  cb8E23e48d22Eae       Karl                      Guyana       East Richard
# 96  CeD220bdAaCfaDf       Lynn                   Sri Lanka       New Bradview
# 97  28CDbC0dFe4b1Db       Fred             Solomon Islands         Ortegaland
# 98  c23d1D9EE8DEB0A     Yvonne                       Aruba    Lake Elijahview
# 99  2354a0E336A91A1   Clarence                    Honduras          Judymouth
#
# [100 rows x 4 columns]

# %%
print(df[["Customer Id","First Name","Country","City"]].to_string())
# Out:
#         Customer Id  First Name                                       Country                 City
# 0   DD37Cf93aecA6Dc      Sheryl                                         Chile         East Leonard
# 1   1Ef7b82A4CAAD10     Preston                                      Djibouti    East Jimmychester
# 2   6F94879bDAfE5a6         Roy                           Antigua and Barbuda        Isabelborough
# 3   5Cef8BFA16c5e3c       Linda                            Dominican Republic           Bensonview
# 4   053d585Ab6b3159      Joanna                    Slovakia (Slovak Republic)       West Priscilla
# 5   2d08FB17EE273F4       Aimee                        Bosnia and Herzegovina        Chavezborough
# 6   EA4d384DfDbBf77      Darren                              Pitcairn Islands             Lake Ana
# 7   0e04AFde9f225dE       Brett                                      Bulgaria              Kimport
# ...

# %%
print(df.loc[96])
# Out:
# Index                                        97
# Customer Id                     CeD220bdAaCfaDf
# First Name                                 Lynn
# Last Name                              Atkinson
# Company                   Ware, Burns and Oneal
# City                               New Bradview
# Country                               Sri Lanka
# Phone 1                         +1-846-706-2218
# Phone 2                            605.413.3198
# Email                         vkemp@ferrell.com
# Subscription Date                    2021-07-10
# Website              https://novak-allison.com/
# Name: 96, dtype: object

# %%
df=pd.read_csv("customers-100.csv", index_col="Customer Id")

# %%
print(df.loc["CeD220bdAaCfaDf"])
# Out:
# Index                                        97
# First Name                                 Lynn
# Last Name                              Atkinson
# Company                   Ware, Burns and Oneal
# City                               New Bradview
# Country                               Sri Lanka
# Phone 1                         +1-846-706-2218
# Phone 2                            605.413.3198
# Email                         vkemp@ferrell.com
# Subscription Date                    2021-07-10
# Website              https://novak-allison.com/
# Name: CeD220bdAaCfaDf, dtype: object

# %%
print(df.to_string())
# Out:
#                  Index  First Name    Last Name                          Company                 City                                       Country                 Phone 1                 Phone 2                               Email Subscription Date                            Website
# Customer Id
# DD37Cf93aecA6Dc      1      Sheryl       Baxter                  Rasmussen Group         East Leonard                                         Chile            229.077.5154        397.884.0519x718            zunigavanessa@smith.info        2020-08-24         http://www.stephenson.com/
# 1Ef7b82A4CAAD10      2     Preston       Lozano                      Vega-Gentry    East Jimmychester                                      Djibouti              5153435776        686-620-1820x944                     vmata@colon.com        2021-04-23              http://www.hobbs.com/
# ...

# %%
print(df.loc["CeD220bdAaCfaDf",["First Name","Last Name"]])
# Out:
# First Name        Lynn
# Last Name     Atkinson
# Name: CeD220bdAaCfaDf, dtype: object

# %%
print(df.loc["CeD220bdAaCfaDf":"2354a0E336A91A1",["First Name","Last Name"]])
# Out:
#                 First Name Last Name
# Customer Id
# CeD220bdAaCfaDf       Lynn  Atkinson
# 28CDbC0dFe4b1Db       Fred    Guerra
# c23d1D9EE8DEB0A     Yvonne    Farmer
# 2354a0E336A91A1   Clarence    Haynes
