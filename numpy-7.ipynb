# %%
import numpy as np

# %%
marks = np.array([50,100,65,85,76])

# %%
print(marks)
# Out:
# [ 50 100  65  85  76]

# %%
print(marks[marks>50])
print(marks)
# Out:
# [100  65  85  76]
# [ 50 100  65  85  76]

# %%
pass_marks=(marks[marks<50])

# %%
print(marks)
# Out:
# [ 50 100  65  85  76]

# %%
arr=np.array([
    [1,2,3],
    [4,5,6]
])

# %%
even = arr[arr%2==0]
print(even)
# Out:
# [2 4 6]

# %%
even = arr[(arr%2==0) |(arr == 1)]
print(even)
# Out:
# [1 2 4 6]

# %%
even = np.where(arr%2==0, arr,5)
print(even)
# Out:
# [[5 2 5]
#  [4 5 6]]
