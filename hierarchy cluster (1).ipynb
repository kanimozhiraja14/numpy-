# %%
import numpy as  np
import pandas  as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from scipy.spatial.distance import pdist, squareform
from scipy.cluster.hierarchy import linkage, dendrogram

# %%
iris =  load_iris()
X=iris.data
y=iris.target

# %%
plt.figure(figsize =(8, 6))
plt.scatter(X[:, 0], X[:, 1],c=y,cmap='viridis')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.title('Iris Dataset')
plt.show()

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(X)

# %%
distance_matrix = pdist(x_scaled, metric='euclidean')
condensed_distance_matrix = squareform(distance_matrix)

# %%
linkage_matrix = linkage(condensed_distance_matrix,method='ward')
# Out:
# C:\Users\kanimozhi\AppData\Local\Temp\ipykernel_15192\675487680.py:1: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linkage_matrix = linkage(condensed_distance_matrix,method='ward')

# %%
plt.figure(figsize=(10,6))
dendrogram(linkage_matrix, labels = iris.target)
plt.title("Dendrogram od Iris Dataset")
plt.show()
